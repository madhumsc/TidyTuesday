# %%
import pandas as pd
import plotnine as p9
from palmerpenguins import load_penguins
from plotnine import *
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv"
df = pd.read_csv(url)

scattered_df=df[["appeared","number_of_users","type"]]


scattered_df.dropna()
scattered_df=scattered_df[scattered_df['appeared']>1950]
scattered_df
# Out:
#       appeared  number_of_users           type
# 0         1995          5550123             pl
# 1         1995          5962666             pl
# 2         1972          3793768             pl
# 3         1991          2818037             pl
# 4         1974          7179119  queryLanguage
# ...        ...              ...            ...
# 4298      1976                0             pl
# 4299      1997                0             pl
# 4300      1955                0             pl
# 4301      1977                0             pl
# 4302      1999                0  queryLanguage
#
# [4273 rows x 3 columns]

# %%
main_10_types_df=scattered_df.groupby(["type"]).agg({"number_of_users":"sum"}).reset_index()
main_10_types_df = main_10_types_df.sort_values(by="number_of_users",ascending=False).head(5)["type"]
main_10_types_df
# Out:
# 24                    pl
# 27         queryLanguage
# 33            textMarkup
# 29    stylesheetLanguage
# 5           dataNotation
# Name: type, dtype: object

# %%
import numpy as np

scattered_df['type'] = np.where(~scattered_df['type'].isin(main_10_types_df), 'other', scattered_df['type'])
scattered_df['type'].unique()
scattered_df
# Out:
#       appeared  number_of_users           type
# 0         1995          5550123             pl
# 1         1995          5962666             pl
# 2         1972          3793768             pl
# 3         1991          2818037             pl
# 4         1974          7179119  queryLanguage
# ...        ...              ...            ...
# 4298      1976                0             pl
# 4299      1997                0             pl
# 4300      1955                0             pl
# 4301      1977                0             pl
# 4302      1999                0  queryLanguage
#
# [4273 rows x 3 columns]

# %%
scattered_df_gp = scattered_df.groupby(["appeared","type"]).agg({"number_of_users":"sum"}).reset_index()
scattered_df_gp
# Out:
#      appeared           type  number_of_users
# 0        1951             pl               60
# 1        1951  queryLanguage            23343
# 2        1952          other                0
# 3        1952             pl               86
# 4        1953          other             4200
# ..        ...            ...              ...
# 249      2022          other               59
# 250      2022             pl            27096
# 251      2022  queryLanguage             4476
# 252      2022     textMarkup             3390
# 253      2023  queryLanguage                2
#
# [254 rows x 3 columns]

# %%
# Import necessary libraries
from plotnine import ggplot, aes, geom_point, facet_wrap, theme_minimal

# Create scatter plots with facets
scatter_plots = (
    ggplot(scattered_df_gp, aes(x='appeared', y='number_of_users')) +
    geom_point() +
    facet_wrap('~type', scales='free_y') +  # Facet by 'type'
    theme_minimal()  # Optional: Customize the theme
)

# Show the plot
print(scatter_plots)

# %%
# Import necessary libraries
from plotnine import ggplot, aes, geom_point, facet_wrap, stat_smooth, theme_minimal

# Create scatter plots with facets and fitted lines
scatter_plots_with_fitted_lines = (
    ggplot(scattered_df_gp, aes(x='appeared', y='number_of_users')) +
    geom_point() +
    stat_smooth(method='lm', se=False, color='red') +  # Add a fitted line (linear regression)
    theme(figure_size=(15, 10))+
    facet_wrap('~type', scales='free_y') +  # Facet by 'type'
    theme_minimal()  # Optional: Customize the theme
)

# Show the plot
print(scatter_plots_with_fitted_lines)

# %%
# Import necessary libraries
from plotnine import ggplot, aes, geom_point, facet_wrap, stat_smooth, theme_minimal

# Create scatter plots with facets and curved fitted lines
scatter_plots_with_curved_lines = (
    ggplot(scattered_df_gp, aes(x='appeared', y='number_of_users')) +
    geom_point() +
    stat_smooth(method='lm', formula='y ~ I(x**2)', se=False, color='red') +  # Add a polynomial fitted line (degree=2)
    facet_wrap('~type', scales='free_y') +  # Facet by 'type'
    theme_minimal()  +# Optional: Customize the theme
   theme(figure_size=(15, 10))
)

# Show the plot
print(scatter_plots_with_curved_lines)

# %%
# Import necessary libraries
from plotnine import ggplot, aes, geom_point, facet_wrap, stat_smooth, theme_minimal

# Create scatter plots with facets and curved fitted lines
scatter_plots_with_curved_lines = (
    ggplot(scattered_df_gp, aes(x='appeared', y='number_of_users')) +
    geom_point() +
    stat_smooth(method='loess', se=False, color='red') +  # Add a loess fitted line
    facet_wrap('~type', scales='free_y') +  # Facet by 'type'
    theme_minimal()  # Optional: Customize the theme
)

# Show the plot
print(scatter_plots_with_curved_lines)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> scatter_plots_with_curved_lines = (
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     ggplot(scattered_df_gp, aes(x='appeared', y='number_of_users')) +
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     geom_point() +
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     theme_minimal()  # Optional: Customize the theme
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a> # Show the plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/10.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> print(scatter_plots_with_curved_lines)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:328, in ggplot._build(self)
#     325 layout.map_position(layers)
#     327 # Apply and map statistics
# --> 328 layers.compute_statistic(layout)
#     329 layers.map_statistic(self)
#     331 # Prepare data in geoms
#     332 # e.g. from y and width to ymin and ymax
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:471, in Layers.compute_statistic(self, layout)
#     469 def compute_statistic(self, layout: Layout):
#     470     for l in self:
# --> 471         l.compute_statistic(layout)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:284, in layer.compute_statistic(self, layout)
#     282 data = self.stat.use_defaults(data)
#     283 data = self.stat.setup_data(data)
# --> 284 data = self.stat.compute_layer(data, params, layout)
#     285 self.data = data
#
# File ~/.local/lib/python3.10/site-packages/plotnine/stats/stat.py:306, in stat.compute_layer(cls, data, params, layout)
#     303     pscales = layout.get_scales(pdata["PANEL"].iat[0])
#     304     return cls.compute_panel(pdata, pscales, **params)
# --> 306 return groupby_apply(data, "PANEL", fn)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/utils.py:596, in groupby_apply(df, cols, func, *args, **kwargs)
#     592 lst = []
#     593 for _, d in df.groupby(cols, observed=True):
#     594     # function fn should be free to modify dataframe d, therefore
#     595     # do not mark d as a slice of df i.e no SettingWithCopyWarning
# --> 596     lst.append(func(d, *args, **kwargs))
#     597 return pd.concat(lst, axis=axis, ignore_index=True)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/stats/stat.py:304, in stat.compute_layer.<locals>.fn(pdata)
#     302     return pdata
#     303 pscales = layout.get_scales(pdata["PANEL"].iat[0])
# --> 304 return cls.compute_panel(pdata, pscales, **params)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/stats/stat.py:340, in stat.compute_panel(cls, data, scales, **params)
#     338 stats = []
#     339 for _, old in data.groupby("group"):
# --> 340     new = cls.compute_group(old, scales, **params)
#     341     unique = uniquecols(old)
#     342     missing = unique.columns.difference(new.columns)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/stats/stat_smooth.py:232, in stat_smooth.compute_group(cls, data, scales, **params)
#     229         rangee = [data["x"].min(), data["x"].max()]
#     230     xseq = np.linspace(rangee[0], rangee[1], n)
# --> 232 return predictdf(data, xseq, **params)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/stats/smoothers.py:47, in predictdf(data, xseq, **params)
#      41     msg = (
#      42         "'method' should either be a string or a function"
#      43         "with the signature `func(data, xseq, **params)`"
#      44     )
#      45     raise PlotnineError()
# ---> 47 return method(data, xseq, **params)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/stats/smoothers.py:370, in loess(data, xseq, **params)
#     367     kwargs["span"] = params["span"]
#     369 lo = loess_klass(data["x"], data["y"], weights, **kwargs)
# --> 370 lo.fit()
#     372 data = pd.DataFrame({"x": xseq})
#     374 if params["se"]:
#
# File _loess.pyx:927, in _loess.loess.fit()
#
# ValueError: b'There are other near singularities as well. 16.565'

# %%
# Import necessary libraries
from plotnine import ggplot, aes, geom_point, facet_wrap, stat_smooth, theme_minimal

# Create scatter plots with facets and curved fitted lines
scatter_plots_with_curved_lines = (
    ggplot(scattered_df_gp, aes(x='appeared', y='number_of_users')) +
    geom_point() +
    stat_smooth(method='lowess', se=False, color='red') +  # Add a lowess fitted line
    facet_wrap('~type', scales='free_y') +  # Facet by 'type'
    theme_minimal()  # Optional: Customize the theme
)

# Show the plot
print(scatter_plots_with_curved_lines)
