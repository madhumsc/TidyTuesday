# %%
import pandas as pd
import plotnine as p9
from palmerpenguins import load_penguins
from plotnine import *

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-04-12/death_source.csv")
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 8005     Zimbabwe  ZWE  2015
# 8006     Zimbabwe  ZWE  2016
# 8007     Zimbabwe  ZWE  2017
# 8008     Zimbabwe  ZWE  2018
# 8009     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Rate)
# 0                                            370.050474
# 1                                            358.978418
# 2                                            352.766453
# 3                                            357.055923
# 4                                            362.970439
# ...                                                 ...
# 8005                                         143.477957
# 8006                                         140.643245
# ...

# %%
df = df.rename(columns={"Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Percent)": "new_column_name"})

# %%
df
# Out:
#            Entity Code  Year  new_column_name
# 0     Afghanistan  AFG  1990        19.623001
# 1     Afghanistan  AFG  1991        19.335193
# 2     Afghanistan  AFG  1992        19.508785
# 3     Afghanistan  AFG  1993        19.677607
# 4     Afghanistan  AFG  1994        19.432528
# ...           ...  ...   ...              ...
# 8005     Zimbabwe  ZWE  2015         8.603630
# 8006     Zimbabwe  ZWE  2016         8.656817
# 8007     Zimbabwe  ZWE  2017         8.690100
# 8008     Zimbabwe  ZWE  2018         8.736245
# 8009     Zimbabwe  ZWE  2019         8.658818
#
# [8010 rows x 4 columns]

# %%
import pandas as pd
from plotnine import *

# Assuming you have the DataFrame with 8009 records named df

# Assuming you have a mapping of countries to continents
country_to_continent = {
    'Afghanistan': 'Asia',
    'Zimbabwe': 'Africa',
    # Add more country-to-continent mappings as needed
}

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['Entity'].map(country_to_continent)

# Create a ggplot chart
ggplot(df, aes(x='Year', y='new_column_name', fill='Continent')) + \
    geom_bar(stat='identity', position='dodge') + \
    labs(title='Summary Statistic by Continent and Year', x='Year', y='Mean Value') + \
    theme_minimal()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:228, in evaluate(aesthetics, data, env)
#     227 try:
# --> 228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'new_column_name' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# ...

# %%
# Out:
# <Figure Size: (1200 x 800)>

# %%
# Assuming you have a DataFrame named df with columns Entity, Code, Year, and new_column_name

# Install and import the necessary libraries
# !pip install plotnine
from plotnine import ggplot, aes, geom_line, labs, theme

# Create a ggplot with Year on the x-axis and new_column_name on the y-axis
# Group the data by Entity and Code (assuming you want separate lines for each Entity and Code combination)
(
    ggplot(df, aes(x='Year', y='new_column_name', color='Entity + Code')) +
    geom_line() +
    labs(title="All-in-One Plot Title", x="Year", y="Your Y-Axis Label", color="Legend Title") +
    theme(figure_size=(12, 8))  # Adjust the figure_size as needed
)
# Out:
# <Figure Size: (1200 x 800)>

# %%
# Assuming you have a DataFrame named df with columns Entity, Code, Year, and new_column_name

# Install and import the necessary libraries
# !pip install plotnine
from plotnine import ggplot, aes, geom_line, labs, theme, facet_wrap

# Create a ggplot with Year on the x-axis and new_column_name on the y-axis
# Group the data by Entity and Code (assuming you want separate lines for each Entity and Code combination)
(
    ggplot(df, aes(x='Year', y='new_column_name', color='Entity + Code')) +
    geom_line() +
    labs(title="All-in-One Plot Title", x="Year", y="Your Y-Axis Label", color="Legend Title") +
    facet_wrap('~Entity', scales='free_y', ncol=3) +  # Facet by Entity with free y-axis scales and 3 columns
    theme(figure_size=(15, 8))  # Adjust the figure_size as needed
)
# Out:
# <Figure Size: (1500 x 800)>

# %%
import pandas as pd
from plotnine import *

# Assuming you have the aggregated DataFrame named aggregated_df

# Create a ggplot chart
ggplot(df, aes(x='Year', y='new_column_name', fill='Continent')) + \
    geom_bar(stat='identity', position='dodge') + \
    labs(title='Summary Statistic by Continent and Year', x='Year', y='Mean Value') + \
    theme_minimal()
# Out:
# <Figure Size: (640 x 480)>

# %%
df
# Out:
#            Entity Code  Year  new_column_name Continent
# 0     Afghanistan  AFG  1990        19.623001      Asia
# 1     Afghanistan  AFG  1991        19.335193      Asia
# 2     Afghanistan  AFG  1992        19.508785      Asia
# 3     Afghanistan  AFG  1993        19.677607      Asia
# 4     Afghanistan  AFG  1994        19.432528      Asia
# ...           ...  ...   ...              ...       ...
# 8005     Zimbabwe  ZWE  2015         8.603630    Africa
# 8006     Zimbabwe  ZWE  2016         8.656817    Africa
# 8007     Zimbabwe  ZWE  2017         8.690100    Africa
# 8008     Zimbabwe  ZWE  2018         8.736245    Africa
# 8009     Zimbabwe  ZWE  2019         8.658818    Africa
#
# [8010 rows x 5 columns]
