# %%
https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv

# %%
import pandas as pd
import plotnine as p9
from palmerpenguins import load_penguins
from plotnine import *

# %%
url="https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv"
df = pd.read_csv(url)
df
# Out:
#                         pldb_id                      title  \
# 0                          java                       Java
# 1                    javascript                 JavaScript
# 2                             c                          C
# 3                        python                     Python
# 4                           sql                        SQL
# ...                         ...                        ...
# 4298                        vtl         Very Tiny Language
# 4299                      wizml                      wizml
# 4300  wolontis-bell-interpreter  Wolontis-Bell Interpreter
# 4301                         xl                         xl
# 4302                        xql                        XQL
#
#                                             description           type  \
# 0                                                   NaN             pl
# 1                                                   NaN             pl
# ...

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Create a bar plot
plot = (ggplot(df, aes(x='title', y='number_of_users', fill='title')) +
        geom_bar(stat='identity') +
        labs(title='Number of Users by Programming Language',
             x='Programming Language',
             y='Number of Users') +
        theme_minimal() +
        theme(axis_text_x = {'angle': 45, 'hjust': 1})
       )

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> plot = (ggplot(df, aes(x='title', y='number_of_users', fill='title')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>         geom_bar(stat='identity') +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>         labs(title='Number of Users by Programming Language',
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>         theme(axis_text_x = {'angle': 45, 'hjust': 1})
# ...

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs, scale_fill_brewer
import pandas as pd

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Create a bar plot
plot = (ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
        geom_bar(stat='identity') +
        labs(title='Top 9 Programming Languages and Other',
             x='Programming Language',
             y='Number of Users') +
        scale_fill_brewer(palette='Set3') +  # You can choose a different palette if needed
        theme_minimal() +
        theme(axis_text_x={'angle': 45, 'hjust': 1})
       )

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a> aggregated_data = pd.concat([top_languages, other_languages])
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a> # Create a bar plot
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> plot = (ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a>         geom_bar(stat='identity') +
# ...

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs, scale_fill_manual
import pandas as pd

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Manually specify colors for each category
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive']  # Adjust the number of colors

# Create a bar plot
plot = (ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
        geom_bar(stat='identity') +
        labs(title='Top 9 Programming Languages and Other',
             x='Programming Language',
             y='Number of Users') +
        scale_fill_manual(values=colors) +
        theme_minimal() +
        theme(axis_text_x={'angle': 45, 'hjust': 1})
       )

# Show the plot
print(plot)
# Out:
# /home/pr/.local/lib/python3.10/site-packages/plotnine/scales/scale_manual.py:45: PlotnineWarning: The palette of scale_fill_manual can return a maximum of 9 values. 4267 were requested from it.
# /home/pr/.local/lib/python3.10/site-packages/plotnine/scales/scale_manual.py:45: PlotnineWarning: The palette of scale_fill_manual can return a maximum of 9 values. 4267 were requested from it.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb Cell 7 line 3
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a> plot = (ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/4.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a>         geom_bar(stat='identity') +
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Manually specify colors for each category
colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive']  # Adjust the number of colors

# Create a bar plot using matplotlib
plt.figure(figsize=(12, 6))
plt.bar(aggregated_data['title'], aggregated_data['number_of_users'], color=colors)
plt.title('Top 9 Programming Languages and Other')
plt.xlabel('Programming Language')
plt.ylabel('Number of Users')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Create a bar plot using plotnine
plot = (
    ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
    geom_bar(stat='identity') +
    labs(title='Top 9 Programming Languages and Other', x='Programming Language', y='Number of Users') +
    theme_minimal() +
    theme(axis_text_x={'angle': 45, 'hjust': 1})
)

# Show the plot
print(plot)
