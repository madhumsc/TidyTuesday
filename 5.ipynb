# %%
import pandas as pd
import plotnine as p9
from palmerpenguins import load_penguins
from plotnine import *

url="https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv"
df = pd.read_csv(url)
df
# Out:
#                         pldb_id                      title  \
# 0                          java                       Java
# 1                    javascript                 JavaScript
# 2                             c                          C
# 3                        python                     Python
# 4                           sql                        SQL
# ...                         ...                        ...
# 4298                        vtl         Very Tiny Language
# 4299                      wizml                      wizml
# 4300  wolontis-bell-interpreter  Wolontis-Bell Interpreter
# 4301                         xl                         xl
# 4302                        xql                        XQL
#
#                                             description           type  \
# 0                                                   NaN             pl
# 1                                                   NaN             pl
# 2                                                   NaN             pl
# 3                                                   NaN             pl
# 4                                                   NaN  queryLanguage
# ...                                                 ...            ...
# 4298  VTL-2 is the second Very Tiny Language develop...             pl
# 4299  WIZML is a sublanguage of VTML. It is a tag-ba...             pl
# 4300                                                NaN             pl
# 4301                                                NaN             pl
# 4302  XQL is a query language designed specifically ...  queryLanguage
#
#       appeared                                   creators  \
# 0         1995                              James Gosling
# 1         1995                               Brendan Eich
# 2         1972                             Dennis Ritchie
# 3         1991                           Guido van Rossum
# 4         1974  Donald D. Chamberlin and Raymond F. Boyce
# ...        ...                                        ...
# 4298      1976              Garry Shannon and Frank McCoy
# 4299      1997                                        NaN
# 4300      1955                                        NaN
# 4301      1977                                        NaN
# 4302      1999                             Jonathan Robie
#
#                        website domain_name  domain_name_registered  \
# 0     https://oracle.com/java/         NaN                     NaN
# 1                          NaN         NaN                     NaN
# 2                          NaN         NaN                     NaN
# 3      https://www.python.org/  python.org                  1995.0
# 4                          NaN         NaN                     NaN
# ...                        ...         ...                     ...
# 4298                       NaN         NaN                     NaN
# 4299                       NaN         NaN                     NaN
# 4300                       NaN         NaN                     NaN
# 4301                       NaN         NaN                     NaN
# 4302                       NaN         NaN                     NaN
#
#                                               reference  ...  \
# 0                                                   NaN  ...
# 1          https://www.w3schools.com/js/js_reserved.asp  ...
# 2      http://www.c4learn.com/c-programming/c-keywords/  ...
# 3     https://www.programiz.com/python-programming/k...  ...
# 4                                                   NaN  ...
# ...                                                 ...  ...
# 4298  http://www.altair680kit.com/manuals/Altair_680...  ...
# 4299  https://sites.hks.harvard.edu/research/Macrome...  ...
# 4300  https://semanticscholar.org/paper/8258aed6f523...  ...
# 4301  https://semanticscholar.org/paper/36672d537f35...  ...
# 4302       http://www.ibiblio.org/xql/xql-tutorial.html  ...
#
#       features_has_semantic_indentation  features_has_line_comments  \
# 0                                 False                        True
# 1                                 False                        True
# 2                                 False                        True
# 3                                  True                        True
# 4                                 False                        True
# ...                                 ...                         ...
# 4298                                NaN                         NaN
# 4299                                NaN                         NaN
# 4300                                NaN                         NaN
# 4301                                NaN                         NaN
# 4302                                NaN                         NaN
#
#       line_comment_token  last_activity number_of_users  number_of_jobs  \
# 0                     //           2022         5550123           85206
# 1                     //           2022         5962666           63993
# 2                     //           2022         3793768           59919
# 3                      #           2022         2818037           46976
# 4                     --           2022         7179119          219617
# ...                  ...            ...             ...             ...
# 4298                 NaN           1976               0               0
# 4299                 NaN           1997               0               0
# 4300                 NaN           1955               0               0
# 4301                 NaN           1977               0               0
# 4302                 NaN           1999               0               0
#
#                     origin_community  central_package_repository_count  \
# 0                   Sun Microsystems                               NaN
# 1                           Netscape                               NaN
# 2                          Bell Labs                               0.0
# 3     Centrum Wiskunde & Informatica                               NaN
# 4                                IBM                               0.0
# ...                              ...                               ...
# 4298                             NaN                               0.0
# 4299                             NaN                               0.0
# 4300                             NaN                               0.0
# 4301                             NaN                               0.0
# 4302                             NaN                               NaN
#
#       file_type  is_open_source
# 0          text             NaN
# 1          text             NaN
# 2          text             NaN
# 3          text             NaN
# 4          text             NaN
# ...         ...             ...
# 4298        NaN             NaN
# 4299        NaN             NaN
# 4300        NaN             NaN
# 4301        NaN             NaN
# 4302        NaN             NaN
#
# [4303 rows x 49 columns]

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Create a bar plot using plotnine
plot = (
    ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
    geom_bar(stat='identity') +
    labs(title='Top 9 Programming Languages and Other', x='Programming Language', y='Number of Users') +
    theme_minimal() +
    theme(axis_text_x={'angle': 45, 'hjust': 1})
)

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a> plot = (
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a>     ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a>     geom_bar(stat='identity') +
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a>     theme(axis_text_x={'angle': 45, 'hjust': 1})
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=24'>25</a> # Show the plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a> print(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:240, in ggplot.draw(self, show)
#     237     self._draw_watermarks()
#     239     # Artist object theming
# --> 240     self.theme.apply()
#     241     figure.set_layout_engine(PlotnineLayoutEngine(self))
#     243 return self.figure
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/theme.py:235, in theme.apply(self)
#     227 """
#     228 Apply this theme, then apply additional modifications in order.
#     229
#    (...)
#     232 base class method is called.
#     233 """
#     234 for th in self.themeables.values():
# --> 235     th.apply(self)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/themeable.py:199, in themeable.apply(self, theme)
#     197 self.apply_figure(theme.figure, theme._targets)
#     198 for ax in theme.axs:
# --> 199     self.apply_ax(ax)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/themeable.py:747, in axis_text_x.apply_ax(self, ax)
#     745 labels = ax.get_xticklabels()  # pyright: ignore
#     746 for l in labels:
# --> 747     l.set(**properties)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1227, in Artist.set(self, **kwargs)
#    1223 def set(self, **kwargs):
#    1224     # docstring and signature are auto-generated via
#    1225     # Artist._update_set_signature_and_docstring() at the end of the
#    1226     # module.
# -> 1227     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'value'

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs, scale_y_log10

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Create a bar plot using plotnine with log scale on y-axis
plot = (
    ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
    geom_bar(stat='identity') +
    scale_y_log10() +  # Log scale on the y-axis
    labs(title='Top 9 Programming Languages and Other', x='Programming Language', y='Number of Users (log scale)') +
    theme_minimal() +
    theme(axis_text_x={'angle': 45, 'hjust': 1})
)

# Show the plot
print(plot)
# Out:
# /home/pr/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> plot = (
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>     ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>     geom_bar(stat='identity') +
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a>     theme(axis_text_x={'angle': 45, 'hjust': 1})
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=25'>26</a> # Show the plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> print(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:240, in ggplot.draw(self, show)
#     237     self._draw_watermarks()
#     239     # Artist object theming
# --> 240     self.theme.apply()
#     241     figure.set_layout_engine(PlotnineLayoutEngine(self))
#     243 return self.figure
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/theme.py:235, in theme.apply(self)
#     227 """
#     228 Apply this theme, then apply additional modifications in order.
#     229
#    (...)
#     232 base class method is called.
#     233 """
#     234 for th in self.themeables.values():
# --> 235     th.apply(self)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/themeable.py:199, in themeable.apply(self, theme)
#     197 self.apply_figure(theme.figure, theme._targets)
#     198 for ax in theme.axs:
# --> 199     self.apply_ax(ax)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/themeable.py:747, in axis_text_x.apply_ax(self, ax)
#     745 labels = ax.get_xticklabels()  # pyright: ignore
#     746 for l in labels:
# --> 747     l.set(**properties)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1227, in Artist.set(self, **kwargs)
#    1223 def set(self, **kwargs):
#    1224     # docstring and signature are auto-generated via
#    1225     # Artist._update_set_signature_and_docstring() at the end of the
#    1226     # module.
# -> 1227     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'value'

# %%
from plotnine import ggplot, aes, geom_bar, labs

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 9 programming languages, and group the rest under 'Other'
top_languages = df.head(9)
other_languages = df.iloc[9:]
aggregated_data = pd.concat([top_languages, other_languages])

# Create a bar plot using plotnine
plot = (
    ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
    geom_bar(stat='identity') +
    labs(title='Top 9 Programming Languages and Other', x='Programming Language', y='Number of Users')
)

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> plot = (
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a>     geom_bar(stat='identity') +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a>     labs(title='Top 9 Programming Languages and Other', x='Programming Language', y='Number of Users')
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> # Show the plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> print(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:240, in ggplot.draw(self, show)
#     237     self._draw_watermarks()
#     239     # Artist object theming
# --> 240     self.theme.apply()
#     241     figure.set_layout_engine(PlotnineLayoutEngine(self))
#     243 return self.figure
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/theme.py:235, in theme.apply(self)
#     227 """
#     228 Apply this theme, then apply additional modifications in order.
#     229
#    (...)
#     232 base class method is called.
#     233 """
#     234 for th in self.themeables.values():
# --> 235     th.apply(self)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/themeable.py:197, in themeable.apply(self, theme)
#     191 def apply(self, theme: Theme):
#     192     """
#     193     Called by the theme to apply the themeable
#     194
#     195     Subclasses shouldn't have to override this method to customize.
#     196     """
# --> 197     self.apply_figure(theme.figure, theme._targets)
#     198     for ax in theme.axs:
#     199         self.apply_ax(ax)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/themes/themeable.py:498, in legend_text_legend.apply_figure(self, figure, targets)
#     496 if not hasattr(text, "_x"):  # textarea
#     497     text = text._text
# --> 498 text.set(**properties)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# KeyboardInterrupt:

# %%
from plotnine import ggplot, aes, geom_bar, labs
import pandas as pd

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_users' column
df = df.dropna(subset=['number_of_users'])

# Sort the DataFrame by 'number_of_users' in descending order
df = df.sort_values(by='number_of_users', ascending=False)

# Keep the top 10 programming languages
top_languages = df.head(10)
aggregated_data = top_languages.copy()

# Create a bar plot using plotnine
plot = (
    ggplot(aggregated_data, aes(x='title', y='number_of_users', fill='title')) +
    geom_bar(stat='identity') +
    labs(title='Top 10 Programming Languages', x='Programming Language', y='Number of Users')
)

# Show the plot
print(plot)

# %%
from plotnine import ggplot, aes, geom_bar, labs
import pandas as pd

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'last_activity' column
df = df.dropna(subset=['last_activity'])

# Sort the DataFrame by 'last_activity' in descending order
df = df.sort_values(by='last_activity', ascending=False)

# Keep the top 10 programming languages
top_languages = df.head(10)
aggregated_data = top_languages.copy()

# Create a bar plot using plotnine
plot = (
    ggplot(aggregated_data, aes(x='title', y='last_activity', fill='title')) +
    geom_bar(stat='identity') +
    labs(title='Last Activity of Top 10 Programming Languages', x='Programming Language', y='Last Activity')
)

# Show the plot
print(plot)

# %%
from plotnine import ggplot, aes, geom_bar, labs
import pandas as pd

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'number_of_jobs' column
df = df.dropna(subset=['number_of_jobs'])

# Sort the DataFrame by 'number_of_jobs' in descending order
df = df.sort_values(by='number_of_jobs', ascending=False)

# Keep the top 10 programming languages
top_languages = df.head(10)
aggregated_data = top_languages.copy()

# Create a bar plot using plotnine
plot = (
    ggplot(aggregated_data, aes(x='title', y='number_of_jobs', fill='title')) +
    geom_bar(stat='identity') +
    labs(title='Number of Jobs for Top 10 Programming Languages', x='Programming Language', y='Number of Jobs')
)

# Show the plot
print(plot)

# %%
from plotnine import ggplot, aes, geom_bar, labs, theme_void

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'is_open_source' column
df = df.dropna(subset=['is_open_source'])

# Sort the DataFrame by 'number_of_jobs' in descending order
df = df.sort_values(by='number_of_jobs', ascending=False)

# Keep the top 10 programming languages
top_languages = df.head(10)
aggregated_data = top_languages.copy()

# Create a pie chart using plotnine
plot = (
    ggplot(aggregated_data, aes(x='factor(1)', fill='is_open_source')) +
    geom_bar(width=1, stat='count') +
    labs(title='Distribution of Open Source and Closed Source Languages',
         x='Programming Languages', y='Count') +
    theme_void()
)

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:228, in evaluate(aesthetics, data, env)
#     227 try:
# --> 228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/categorical.py:403, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     401 if not is_list_like(values):
#     402     # GH#38433
# --> 403     raise TypeError("Categorical input must be list-like")
#     405 # null_mask indicates missing values we want to exclude from inference.
#     406 # This means: only missing values in list-likes (not arrays/ndframes).
#
# TypeError: Categorical input must be list-like
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> plot = (
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a>     ggplot(aggregated_data, aes(x='factor(1)', fill='is_open_source')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a>     geom_bar(width=1, stat='count') +
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=20'>21</a>     theme_void()
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> # Show the plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a> print(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:314, in ggplot._build(self)
#     310 layout.setup(layers, self)
#     312 # Compute aesthetics to produce data with generalised
#     313 # variable names
# --> 314 layers.compute_aesthetics(self)
#     316 # Transform data using all scales
#     317 layers.transform(scales)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:467, in Layers.compute_aesthetics(self, plot)
#     465 def compute_aesthetics(self, plot: Ggplot):
#     466     for l in self:
# --> 467         l.compute_aesthetics(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:260, in layer.compute_aesthetics(self, plot)
#     253 def compute_aesthetics(self, plot: Ggplot):
#     254     """
#     255     Return a dataframe where the columns match the aesthetic mappings
#     256
#     257     Transformations like 'factor(cyl)' and other
#     258     expression evaluation are  made in here
#     259     """
# --> 260     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     261     evaled_aes = aes(**{str(col): col for col in evaled})
#     262     plot.scales.add_defaults(evaled, evaled_aes)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:230, in evaluate(aesthetics, data, env)
#     228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
# --> 230     raise PlotnineError(_TPL_EVAL_FAIL.format(ae, col, str(e)))
#     232 try:
#     233     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'factor(1)' (original error: Categorical input must be list-like)"

# %%
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Sort the DataFrame by 'appeared'
df = df.sort_values(by='appeared', ascending=True)

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 9 line 6
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> # Assuming you have the DataFrame named 'df' with the relevant columns
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> # Filter out rows with NaN values in 'appeared' column
# ----> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> df = df.dropna(subset=['appeared'])
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> # Convert 'appeared' to integer for plotting
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> df['appeared'] = df['appeared'].astype(int)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column
bins = range(df['appeared'].min(), df['appeared'].max() + 2, 2)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 2-year intervals)',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Remove rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Create bins for the 'appeared' column
bins = range(df['appeared'].min(), df['appeared'].max() + 2, 2)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 2-year intervals)',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column
bins = range(df['appeared'].min(), df['appeared'].max() + 2, 2)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 2-year intervals)',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 12 line 7
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> # Assuming you have the DataFrame named 'df' with the relevant columns
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> # Drop rows with NaN values in 'appeared' column
# ----> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a> df = df.dropna(subset=['appeared'])
#       <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a> # Convert 'appeared' to integer for plotting
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X35sZmlsZQ%3D%3D?line=9'>10</a> df['appeared'] = df['appeared'].astype(int)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter out rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Remove rows with NaN values in 'appeared' column
df = df.dropna(subset=['appeared'])

# Create bins for the 'appeared' column with 5-year intervals
bins = range(df['appeared'].min(), df['appeared'].max() + 6, 5)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 5-year intervals)',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'appeared' column
df = df.dropna(subset=['appeared'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
df = df[(df['appeared'] >= 1963) & (df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column with 5-year intervals up to 2023
bins = range(df['appeared'].min(), min(df['appeared'].max() + 6, 2024), 5)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
df = df.dropna(subset=['appeared_bin'])

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 5-year intervals)',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'appeared' column
df = df.dropna(subset=['appeared'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
df = df[(df['appeared'] >= 1963) & (df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column with 3-year intervals up to 2023
bins = range(df['appeared'].min(), min(df['appeared'].max() + 4, 2024), 3)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
df = df.dropna(subset=['appeared_bin'])

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)')) +
    geom_bar(stat='count') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 3-year intervals)',
         x='Year of Appearance', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'appeared' and 'type' columns
df = df.dropna(subset=['appeared', 'type'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
df = df[(df['appeared'] >= 1963) & (df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column with 3-year intervals up to 2023
bins = range(df['appeared'].min(), min(df['appeared'].max() + 6, 2024), 5)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
df = df.dropna(subset=['appeared_bin'])

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)', fill='type')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Distribution of Programming Languages by Appearance Year and Type (Binned into 3-year intervals)',
         x='Year of Appearance', y='Count', fill='Language Type') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
from plotnine import ggplot, aes, geom_bar, facet_wrap, theme_minimal, labs

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'appeared' and 'type' columns
df = df.dropna(subset=['appeared', 'type'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
df = df[(df['appeared'] >= 1963) & (df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column with 3-year intervals up to 2023
bins = range(df['appeared'].min(), min(df['appeared'].max() + 4, 2024), 3)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
df = df.dropna(subset=['appeared_bin'])

# Create a clustered bar chart using plotnine
plot = (
    ggplot(df, aes(x='appeared_bin', fill='type')) +
    geom_bar() +
    facet_wrap('~type', scales='free_y', ncol=1) +
    theme_minimal() +
    labs(title='Correlation between Programming Language Type and Appearance Year',
         x='Year of Appearance (Binned)', y='Count')
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Filter rows for procedural programming languages
procedural_df = df[df['type'] == 'pl']

# Drop rows with NaN values in the 'appeared' column
procedural_df = procedural_df.dropna(subset=['appeared'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
procedural_df = procedural_df[(procedural_df['appeared'] >= 1963) & (procedural_df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
procedural_df['appeared'] = procedural_df['appeared'].astype(int)

# Create bins for the 'appeared' column with 5-year intervals up to 2023
bins = range(procedural_df['appeared'].min(), min(procedural_df['appeared'].max() + 6, 2024), 5)
procedural_df['appeared_bin'] = pd.cut(procedural_df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
procedural_df = procedural_df.dropna(subset=['appeared_bin'])

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(procedural_df, aes(x='factor(appeared_bin)', fill='type')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Distribution of Procedural Programming Languages by Appearance Year (Binned into 5-year intervals)',
         x='Year of Appearance', y='Count', fill='Language Type') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Replace 'type' values other than 'pl' with 'Other'
df['type'] = df['type'].where(df['type'] == 'pl', 'Other')

# Drop rows with NaN values in the 'appeared' column
df = df.dropna(subset=['appeared'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
df = df[(df['appeared'] >= 1963) & (df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column with 5-year intervals up to 2023
bins = range(df['appeared'].min(), min(df['appeared'].max() + 6, 2024), 5)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
df = df.dropna(subset=['appeared_bin'])

# Create a bar chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)', fill='type')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Distribution of Programming Languages by Appearance Year (Binned into 5-year intervals)',
         x='Year of Appearance', y='Count', fill='Language Type') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_line, geom_point, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'appeared' and 'is_open_source' columns
df = df.dropna(subset=['appeared', 'is_open_source'])

# Filter 'appeared' values to be within the expected range (1963 to 2023)
df = df[(df['appeared'] >= 1963) & (df['appeared'] <= 2023)]

# Convert 'appeared' to integer for plotting
df['appeared'] = df['appeared'].astype(int)

# Create bins for the 'appeared' column with 5-year intervals up to 2023
bins = range(df['appeared'].min(), min(df['appeared'].max() + 6, 2024), 5)
df['appeared_bin'] = pd.cut(df['appeared'], bins=bins, right=False, include_lowest=True)

# Drop rows with NaN values in the 'appeared_bin' column
df = df.dropna(subset=['appeared_bin'])

# Create a trend chart using plotnine with angled x-axis labels, increased space, and widened x-axis
plot = (
    ggplot(df, aes(x='factor(appeared_bin)', y='..count..', color='is_open_source')) +
    geom_line() +
    geom_point() +
    labs(title='Trend of Open Source vs. Closed Source Programming Languages by Appearance Year (Binned into 5-year intervals)',
         x='Year of Appearance', y='Count', color='Is Open Source') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}),
          figure_size=(12, 6))  # Adjust the figure size as needed
)

# Show the plot
print(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:228, in evaluate(aesthetics, data, env)
#     227 try:
# --> 228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'count' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb Cell 19 line 3
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=22'>23</a> plot = (
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=23'>24</a>     ggplot(df, aes(x='factor(appeared_bin)', y='..count..', color='is_open_source')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=24'>25</a>     geom_line() +
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=30'>31</a>           figure_size=(12, 6))  # Adjust the figure size as needed
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=31'>32</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=33'>34</a> # Show the plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/5.ipynb#X24sZmlsZQ%3D%3D?line=34'>35</a> print(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:329, in ggplot._build(self)
#     327 # Apply and map statistics
#     328 layers.compute_statistic(layout)
# --> 329 layers.map_statistic(self)
#     331 # Prepare data in geoms
#     332 # e.g. from y and width to ymin and ymax
#     333 layers.setup_data()
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:475, in Layers.map_statistic(self, plot)
#     473 def map_statistic(self, plot: Ggplot):
#     474     for l in self:
# --> 475         l.map_statistic(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:297, in layer.map_statistic(self, plot)
#     295 # Mixin default stat aesthetic mappings
#     296 aesthetics = self.mapping.inherit(self.stat.DEFAULT_AES)
# --> 297 stat_data = evaluate(aesthetics._calculated, data, plot.environment)
#     299 if not len(stat_data):
#     300     return
#
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:230, in evaluate(aesthetics, data, env)
#     228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
# --> 230     raise PlotnineError(_TPL_EVAL_FAIL.format(ae, col, str(e)))
#     232 try:
#     233     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'y' mapping: 'count' (original error: name 'count' is not defined)"

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'is_open_source' column
df = df.dropna(subset=['is_open_source'])

# Create a bar chart using plotnine
plot = (
    ggplot(df, aes(x='is_open_source', fill='is_open_source')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Number of Open Source vs. Closed Source Programming Languages',
         x='Is Open Source', y='Count', fill='Is Open Source') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}))
)

# Show the plot
print(plot)

# %%
# !pip install scikit-misc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-misc in /home/pr/.local/lib/python3.10/site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.22.3 in /home/pr/.local/lib/python3.10/site-packages (from scikit-misc) (1.26.2)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'origin_community' column
df = df.dropna(subset=['origin_community'])

# Create a bar chart using plotnine
plot = (
    ggplot(df, aes(x='origin_community', fill='factor(type)')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Count of Programming Languages by Origin Community',
         x='Origin Community', y='Count', fill='Language Type') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}))
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'origin_community' column
df = df.dropna(subset=['origin_community'])

# Get the top 10 origin communities
top_origin_communities = df['origin_community'].value_counts().nlargest(10).index
df_top_10 = df[df['origin_community'].isin(top_origin_communities)]

# Create a bar chart using plotnine
plot = (
    ggplot(df_top_10, aes(x='origin_community', fill='factor(type)')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Top 10 Origin Communities of Programming Languages',
         x='Origin Community', y='Count', fill='Language Type') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}))
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'origin_community' column
df = df.dropna(subset=['origin_community'])

# Create a bar chart using plotnine
plot = (
    ggplot(df, aes(x='origin_community', fill='factor(type)')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Programming Languages Count by Origin Community',
         x='Origin Community', y='Count', fill='Language Type') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}))
)

# Show the plot
print(plot)

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, labs, theme_minimal, theme, element_text

# Assuming you have the DataFrame named 'df' with the relevant columns

# Drop rows with NaN values in the 'origin_community' column
df = df.dropna(subset=['origin_community'])

# Get the top 10 origin communities
top_10_origin_communities = df['origin_community'].value_counts().nlargest(10).index
df_top_10 = df[df['origin_community'].isin(top_10_origin_communities)]

# Create a bar chart using plotnine
plot = (
    ggplot(df_top_10, aes(x='origin_community')) +
    geom_bar(stat='count', position='dodge') +
    labs(title='Top 10 Programming Languages Count by Origin Community',
         x='Origin Community', y='Count') +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1, margin={'b': 15}))
)

# Show the plot
print(plot)
