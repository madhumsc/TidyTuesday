# %%
from plotnine import ggplot, aes, geom_bar, labs, theme
import pandas as pd

url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv"
language_by_user_df = pd.read_csv(url)

# Filter out rows with NaN values in 'number_of_jobs' and 'number_of_users' columns
language_by_user_df = language_by_user_df.dropna(subset=['number_of_jobs', 'number_of_users'])

# Sort the DataFrame by 'number_of_jobs' and 'number_of_users' in descending order
language_by_user_df = language_by_user_df.sort_values(by=['number_of_jobs', 'number_of_users'], ascending=False)

# Keep the top 10 programming languages
top_languages = language_by_user_df.head(10).copy()

# Create a bar plot for the number of jobs and number of users side by side
combined_plot = (
    ggplot(top_languages, aes(x='reorder(title, -number_of_jobs)', fill='variable')) +
    geom_bar(aes(y='number_of_jobs'), stat='identity', position='dodge', color='blue', fill='blue', alpha=0.7) +
    geom_bar(aes(y='number_of_users'), stat='identity', position='dodge', color='red', fill='red', alpha=0.7) +
    labs(title='Number of Jobs and Users for Top 10 Programming Languages', x='Programming Language', y='Count') +
    theme(figure_size=(15, 10))
)

# Show the combined plot
print(combined_plot)

# %%
from plotnine import ggplot, aes, geom_bar, labs, theme
import pandas as pd

url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv"
language_by_user_df = pd.read_csv(url)

# Filter out rows with NaN values in 'number_of_jobs' and 'number_of_users' columns
language_by_user_df = language_by_user_df.dropna(subset=['number_of_jobs', 'number_of_users'])

# Sort the DataFrame by 'number_of_jobs' and 'number_of_users' in descending order
language_by_user_df = language_by_user_df.sort_values(by=['number_of_jobs', 'number_of_users'], ascending=False)

# Keep the top 10 programming languages
top_languages = language_by_user_df.head(10).copy()

# Create a bar plot for the number of jobs and number of users side by side
combined_plot = (
    ggplot(top_languages, aes(x='reorder(title, -number_of_jobs)', fill='variable')) +
    geom_bar(aes(y='number_of_jobs'), stat='identity', position='dodge', color='blue', fill='blue', alpha=0.7) +
    geom_bar(aes(y='number_of_users'), stat='identity', position='dodge', color='red', fill='red', alpha=0.7) +
    labs(title='Number of Jobs and Users for Top 10 Programming Languages', x='Programming Language', y='Count') +
    labs(fill='Legend Title') +  # Add this line for the legend
    theme(figure_size=(15, 10))
)

# Show the combined plot
print(combined_plot)

# %%
from plotnine import ggplot, aes, geom_bar, geom_text, labs, theme

url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-03-21/languages.csv"
language_by_user_df = pd.read_csv(url)

# Filter out rows with NaN values in 'number_of_jobs' and 'number_of_users' columns
language_by_user_df = language_by_user_df.dropna(subset=['number_of_jobs', 'number_of_users'])

# Sort the DataFrame by 'number_of_jobs' and 'number_of_users' in descending order
language_by_user_df = language_by_user_df.sort_values(by=['number_of_jobs', 'number_of_users'], ascending=False)

# Keep the top 10 programming languages
top_languages = language_by_user_df.head(10).copy()

# Create a bar plot for the number of jobs and number of users side by side
combined_plot = (
    ggplot(top_languages, aes(x='reorder(title, -number_of_jobs)', fill='variable')) +
    geom_bar(aes(y='number_of_jobs'), stat='identity', position='dodge', alpha=0.7) +
    geom_bar(aes(y='number_of_users'), stat='identity', position='dodge', alpha=0.7) +
    geom_text(x=10.5, y=3000, label='Number of Jobs', color='blue') +
    geom_text(x=10.5, y=2800, label='Number of Users', color='red') +
    labs(title='Number of Jobs and Users for Top 10 Programming Languages', x='Programming Language', y='Count') +
    labs(fill='Legend Title') +
    theme(figure_size=(15, 10))
)

# Show the combined plot
print(combined_plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:228, in evaluate(aesthetics, data, env)
#     227 try:
# --> 228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'variable' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# /home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> combined_plot = (
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a>     ggplot(top_languages, aes(x='reorder(title, -number_of_jobs)', fill='variable')) +
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a>     geom_bar(aes(y='number_of_jobs'), stat='identity', position='dodge', alpha=0.7) +
#    (...)
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a>     theme(figure_size=(15, 10))
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a> )
#      <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a> # Show the combined plot
# ---> <a href='vscode-notebook-cell:/home/pr/Desktop/MSc/Source/TidyTuesday/final/3.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> print(combined_plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:314, in ggplot._build(self)
#     310 layout.setup(layers, self)
#     312 # Compute aesthetics to produce data with generalised
#     313 # variable names
# --> 314 layers.compute_aesthetics(self)
#     316 # Transform data using all scales
#     317 layers.transform(scales)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:467, in Layers.compute_aesthetics(self, plot)
#     465 def compute_aesthetics(self, plot: Ggplot):
#     466     for l in self:
# --> 467         l.compute_aesthetics(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:260, in layer.compute_aesthetics(self, plot)
#     253 def compute_aesthetics(self, plot: Ggplot):
#     254     """
#     255     Return a dataframe where the columns match the aesthetic mappings
#     256
#     257     Transformations like 'factor(cyl)' and other
#     258     expression evaluation are  made in here
#     259     """
# --> 260     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     261     evaled_aes = aes(**{str(col): col for col in evaled})
#     262     plot.scales.add_defaults(evaled, evaled_aes)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:230, in evaluate(aesthetics, data, env)
#     228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
# --> 230     raise PlotnineError(_TPL_EVAL_FAIL.format(ae, col, str(e)))
#     232 try:
#     233     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'fill' mapping: 'variable' (original error: name 'variable' is not defined)"
